# %%
from net.hcq import HCQ
import numpy as np
from net.data import get_dataloader
import torch
import time
import json
from collections import OrderedDict
import os

# %% [markdown]
# ## Acc Loss: 1.0

# %%
acc_loss = 1.0
linkage_name='single'
file_path = 'model/1.1 Pipeline Experiments/acc loss {} linkage {}'.format(str(acc_loss), linkage_name)
if not os.path.exists(file_path):
    os.makedirs(file_path)
train_loader, valid_loader, test_loader = get_dataloader(type='cifar10', data_root='../data', batch_size=64)
net = HCQ(10)
net.load_from_pretrained_model('model/resnet18_cifar10_baseline.pth')
valid_acc = net.compute_acc(valid_loader)
test_acc = net.compute_acc(test_loader)
print('Orignal valid accuracy:{:.2f}% | Original Test accuracy:{:.2f}% | Minimal valid accuracy:{:.2f}%'.format(valid_acc, test_acc, valid_acc - acc_loss))

'''
Use designed linkage function to quantize all layers of alexnet:
'''
cluster_num_dict = OrderedDict()
acc_dict = OrderedDict()
time_dict = OrderedDict()
for lower_bound in range(5, 2, -1):
    print('\n########################## Lower bound {} ##########################\n'.format(lower_bound))
    for layer_name in net.layers:
        start_time = time.time()
        print('---------------------- Quantize Layer {} ------------------------'.format(layer_name))
        code_book, weights = net.hcq_initialization(layer_name, 'single')
        total_cluster_num = []
        total_acc = []
        for iteration in range(10):
            max_idx = np.max(code_book)
            code_book, centroids, clusters_num_list, acc_list = net.quantize_layer_under_acc_loss(
                layer_name=layer_name,
                code_book=code_book,
                linkage_name=linkage_name,
                clusters_num_lower_bound=2**lower_bound,
                baseline_acc=valid_acc - acc_loss,
                valid_loader=valid_loader)
            if max_idx == np.max(code_book):
                break
            net.fine_tune(layer_name, code_book, 1, 1e-4, train_loader, valid_loader, test_loader, 
                          show_interval = 50, sample_rate=0.2)
            total_cluster_num = np.concatenate((total_cluster_num, clusters_num_list))
            total_acc = np.concatenate((total_acc, acc_list))
        cluster_num_dict[layer_name]= list(total_cluster_num)
        acc_dict[layer_name] = list(total_acc)
        time_dict[layer_name] = time.time() - start_time
        net.save_model(os.path.join(file_path, 'model.pth'))

    '''
    Record Data
    '''
    with open(os.path.join(file_path, 'acc_dict.json'), 'w') as f:
        f.write(json.dumps(acc_dict))
    with open(os.path.join(file_path, 'clusters_nums_dict.json'), 'w') as f:
        f.write(json.dumps(cluster_num_dict))
    with open(os.path.join(file_path, 'time_dict.json'), 'w') as f:
        f.write(json.dumps(time_dict))
# Out:
# Orignal valid accuracy:100.00% | Original Test accuracy:92.60% | Minimal valid accuracy:99.00%
#
# ########################## Lower bound 5 ##########################
#
# ---------------------- Quantize Layer block 1 Conv 1 1 ------------------------
# Clusters:240 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 0.38 mins
# Clusters:220 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 0.77 mins
# Clusters:200 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 1.15 mins
# Clusters:190 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 1.52 mins
# Clusters:180 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 1.90 mins
# Clusters:170 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 2.28 mins
# Clusters:160 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 2.67 mins
# Clusters:150 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 3.06 mins
# Clusters:140 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 3.43 mins
# Clusters:130 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 3.81 mins
# Clusters:120 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 4.18 mins
# Clusters:110 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 4.55 mins
# Clusters:100 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 4.93 mins
# Clusters: 95 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 5.32 mins
# Clusters: 90 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 5.73 mins
# Clusters: 85 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 6.11 mins
# Clusters: 80 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 6.50 mins
# Clusters: 75 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 6.89 mins
# Clusters: 70 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 7.28 mins
# Clusters: 65 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 7.64 mins
# Clusters: 62 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 8.02 mins
# Clusters: 60 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 8.39 mins
# Clusters: 58 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 8.76 mins
# Clusters: 56 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 9.15 mins
# Clusters: 54 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 9.53 mins
# Clusters: 52 | Validation Accuracy:100.00% | Accuracy change: 0.05% | Time: 9.92 mins
# Clusters: 50 | Validation Accuracy:99.85% | Accuracy change: -0.10% | Time: 10.32 mins
# Clusters: 48 | Validation Accuracy:99.85% | Accuracy change: -0.10% | Time: 10.68 mins
# Clusters: 46 | Validation Accuracy:99.90% | Accuracy change: -0.05% | Time: 11.05 mins
# Clusters: 44 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 11.41 mins
# Clusters: 42 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 11.82 mins
# Clusters: 40 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 12.19 mins
# Clusters: 38 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 12.55 mins
# Clusters: 36 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 12.92 mins
# Clusters: 34 | Validation Accuracy:99.95% | Accuracy change: 0.00% | Time: 13.29 mins
# Clusters: 32 | Validation Accuracy:99.65% | Accuracy change: -0.30% | Time: 13.66 mins
# Epoch: 001/001 | Batch 050/750 | Test Accuracy: 92.14% | Validation Accuracy: 99.70% | Time: 3.88 mins
# Epoch: 001/001 | Batch 100/750 | Test Accuracy: 92.01% | Validation Accuracy: 99.70% | Time: 7.81 mins
# Epoch: 001/001 | Batch 150/750 | Test Accuracy: 92.15% | Validation Accuracy: 99.55% | Time: 11.76 mins
# ---------------------- Quantize Layer block 1 Conv 1 2 ------------------------
# Clusters:220 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 0.38 mins
# Clusters:200 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 0.77 mins
# Clusters:190 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 1.15 mins
# Clusters:180 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 1.52 mins
# Clusters:170 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 1.90 mins
# Clusters:160 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 2.28 mins
# Clusters:150 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 2.65 mins
# Clusters:140 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 3.02 mins
# Clusters:130 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 3.40 mins
# Clusters:120 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 3.78 mins
# Clusters:110 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 4.15 mins
# Clusters:100 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 4.53 mins
# Clusters: 95 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 4.90 mins
# Clusters: 90 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 5.28 mins
# Clusters: 85 | Validation Accuracy:99.55% | Accuracy change: 0.00% | Time: 5.66 mins
# Clusters: 80 | Validation Accuracy:99.60% | Accuracy change: 0.05% | Time: 6.04 mins
# Clusters: 75 | Validation Accuracy:99.65% | Accuracy change: 0.10% | Time: 6.42 mins
# Clusters: 70 | Validation Accuracy:99.65% | Accuracy change: 0.10% | Time: 6.80 mins
# Clusters: 65 | Validation Accuracy:99.60% | Accuracy change: 0.05% | Time: 7.18 mins
# Clusters: 62 | Validation Accuracy:99.65% | Accuracy change: 0.10% | Time: 7.55 mins
# Clusters: 60 | Validation Accuracy:99.70% | Accuracy change: 0.15% | Time: 7.92 mins
# Clusters: 58 | Validation Accuracy:99.65% | Accuracy change: 0.10% | Time: 8.30 mins
# Clusters: 56 | Validation Accuracy:99.65% | Accuracy change: 0.10% | Time: 8.67 mins
# Clusters: 54 | Validation Accuracy:99.65% | Accuracy change: 0.10% | Time: 9.04 mins
# Clusters: 52 | Validation Accuracy:99.70% | Accuracy change: 0.15% | Time: 9.41 mins
# Clusters: 50 | Validation Accuracy:99.70% | Accuracy change: 0.15% | Time: 9.78 mins
# Clusters: 48 | Validation Accuracy:99.75% | Accuracy change: 0.20% | Time: 10.16 mins
# Clusters: 46 | Validation Accuracy:99.65% | Accuracy change: 0.10% | Time: 10.53 mins
# Clusters: 44 | Validation Accuracy:99.65% | Accuracy change: 0.10% | Time: 10.89 mins
# Clusters: 42 | Validation Accuracy:99.35% | Accuracy change: -0.20% | Time: 11.26 mins
# Clusters: 40 | Validation Accuracy:99.15% | Accuracy change: -0.40% | Time: 11.63 mins
# Clusters: 38 | Validation Accuracy:99.15% | Accuracy change: -0.40% | Time: 12.00 mins
# Clusters: 36 | Validation Accuracy:99.15% | Accuracy change: -0.40% | Time: 12.37 mins
# Clusters: 34 | Validation Accuracy:99.25% | Accuracy change: -0.30% | Time: 12.73 mins
# Clusters: 32 | Validation Accuracy:99.20% | Accuracy change: -0.35% | Time: 13.11 mins
# Epoch: 001/001 | Batch 050/750 | Test Accuracy: 91.36% | Validation Accuracy: 99.30% | Time: 3.88 mins
# Epoch: 001/001 | Batch 100/750 | Test Accuracy: 91.45% | Validation Accuracy: 99.30% | Time: 7.79 mins
# Epoch: 001/001 | Batch 150/750 | Test Accuracy: 91.42% | Validation Accuracy: 99.35% | Time: 11.66 mins
# ---------------------- Quantize Layer block 1 Conv 2 1 ------------------------
# Clusters:220 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 0.38 mins
# Clusters:200 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 0.78 mins
# Clusters:190 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 1.16 mins
# Clusters:180 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 1.54 mins
# Clusters:170 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 1.92 mins
# Clusters:160 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 2.30 mins
# Clusters:150 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 2.67 mins
# Clusters:140 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 3.05 mins
# Clusters:130 | Validation Accuracy:99.45% | Accuracy change: 0.00% | Time: 3.44 mins
# Clusters:120 | Validation Accuracy:99.40% | Accuracy change: -0.05% | Time: 3.82 mins
# Clusters:110 | Validation Accuracy:99.40% | Accuracy change: -0.05% | Time: 4.19 mins
# Clusters:100 | Validation Accuracy:99.40% | Accuracy change: -0.05% | Time: 4.57 mins
# Clusters: 95 | Validation Accuracy:99.40% | Accuracy change: -0.05% | Time: 4.94 mins
# Clusters: 90 | Validation Accuracy:99.40% | Accuracy change: -0.05% | Time: 5.32 mins
# Clusters: 85 | Validation Accuracy:99.40% | Accuracy change: -0.05% | Time: 5.69 mins
# Clusters: 80 | Validation Accuracy:99.35% | Accuracy change: -0.10% | Time: 6.07 mins
# Clusters: 75 | Validation Accuracy:99.35% | Accuracy change: -0.10% | Time: 6.45 mins
# Clusters: 70 | Validation Accuracy:99.35% | Accuracy change: -0.10% | Time: 6.83 mins
# Clusters: 65 | Validation Accuracy:99.35% | Accuracy change: -0.10% | Time: 7.20 mins
# Clusters: 62 | Validation Accuracy:99.35% | Accuracy change: -0.10% | Time: 7.58 mins
# Clusters: 60 | Validation Accuracy:99.25% | Accuracy change: -0.20% | Time: 7.96 mins
# Clusters: 58 | Validation Accuracy:99.30% | Accuracy change: -0.15% | Time: 8.34 mins
# Clusters: 56 | Validation Accuracy:99.30% | Accuracy change: -0.15% | Time: 8.71 mins
# Clusters: 54 | Validation Accuracy:99.25% | Accuracy change: -0.20% | Time: 9.08 mins
# Clusters: 52 | Validation Accuracy:99.25% | Accuracy change: -0.20% | Time: 9.46 mins
# End quantization
# Epoch: 001/001 | Batch 050/750 | Test Accuracy: 91.39% | Validation Accuracy: 99.05% | Time: 3.99 mins
# Epoch: 001/001 | Batch 100/750 | Test Accuracy: 91.38% | Validation Accuracy: 99.10% | Time: 8.03 mins
# Epoch: 001/001 | Batch 150/750 | Test Accuracy: 91.44% | Validation Accuracy: 99.15% | Time: 11.96 mins
# Clusters: 50 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 0.37 mins
# Clusters: 48 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 0.74 mins
# Clusters: 46 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 1.12 mins
# Clusters: 44 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 1.49 mins
# Clusters: 42 | Validation Accuracy:99.20% | Accuracy change: 0.05% | Time: 1.87 mins
# Clusters: 40 | Validation Accuracy:99.20% | Accuracy change: 0.05% | Time: 2.25 mins
# Clusters: 38 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 2.62 mins
# Clusters: 36 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 2.99 mins
# Clusters: 34 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 3.42 mins
# Clusters: 32 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 3.80 mins
# Epoch: 001/001 | Batch 050/750 | Test Accuracy: 91.46% | Validation Accuracy: 99.25% | Time: 3.88 mins
# Epoch: 001/001 | Batch 100/750 | Test Accuracy: 91.45% | Validation Accuracy: 99.30% | Time: 7.84 mins
# Epoch: 001/001 | Batch 150/750 | Test Accuracy: 91.59% | Validation Accuracy: 99.30% | Time: 11.80 mins
# ---------------------- Quantize Layer block 1 Conv 2 2 ------------------------
# Clusters:220 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 0.40 mins
# Clusters:200 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 0.80 mins
# Clusters:190 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 1.19 mins
# Clusters:180 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 1.57 mins
# Clusters:170 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 1.96 mins
# Clusters:160 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 2.34 mins
# Clusters:150 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 2.72 mins
# Clusters:140 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 3.10 mins
# Clusters:130 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 3.48 mins
# Clusters:120 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 3.87 mins
# Clusters:110 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 4.25 mins
# Clusters:100 | Validation Accuracy:99.25% | Accuracy change: -0.05% | Time: 4.63 mins
# Clusters: 95 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 5.01 mins
# Clusters: 90 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 5.40 mins
# Clusters: 85 | Validation Accuracy:99.35% | Accuracy change: 0.05% | Time: 5.78 mins
# Clusters: 80 | Validation Accuracy:99.35% | Accuracy change: 0.05% | Time: 6.17 mins
# Clusters: 75 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 6.54 mins
# Clusters: 70 | Validation Accuracy:99.35% | Accuracy change: 0.05% | Time: 6.93 mins
# Clusters: 65 | Validation Accuracy:99.35% | Accuracy change: 0.05% | Time: 7.30 mins
# Clusters: 62 | Validation Accuracy:99.40% | Accuracy change: 0.10% | Time: 7.67 mins
# Clusters: 60 | Validation Accuracy:99.25% | Accuracy change: -0.05% | Time: 8.05 mins
# Clusters: 58 | Validation Accuracy:99.25% | Accuracy change: -0.05% | Time: 8.43 mins
# Clusters: 56 | Validation Accuracy:99.25% | Accuracy change: -0.05% | Time: 8.80 mins
# Clusters: 54 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 9.19 mins
# Clusters: 52 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 9.56 mins
# Clusters: 50 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 9.94 mins
# Clusters: 48 | Validation Accuracy:99.35% | Accuracy change: 0.05% | Time: 10.31 mins
# Clusters: 46 | Validation Accuracy:99.30% | Accuracy change: 0.00% | Time: 10.69 mins
# Clusters: 44 | Validation Accuracy:99.20% | Accuracy change: -0.10% | Time: 11.07 mins
# End quantization
# Epoch: 001/001 | Batch 050/750 | Test Accuracy: 90.93% | Validation Accuracy: 99.10% | Time: 3.89 mins
# Epoch: 001/001 | Batch 100/750 | Test Accuracy: 90.90% | Validation Accuracy: 99.15% | Time: 7.79 mins
# Epoch: 001/001 | Batch 150/750 | Test Accuracy: 91.07% | Validation Accuracy: 99.20% | Time: 11.67 mins
# Clusters: 42 | Validation Accuracy:99.20% | Accuracy change: 0.05% | Time: 0.37 mins
# Clusters: 40 | Validation Accuracy:99.20% | Accuracy change: 0.05% | Time: 0.75 mins
# Clusters: 38 | Validation Accuracy:99.20% | Accuracy change: 0.05% | Time: 1.12 mins
# Clusters: 36 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 1.49 mins
# Clusters: 34 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 1.86 mins
# Clusters: 32 | Validation Accuracy:99.15% | Accuracy change: 0.00% | Time: 2.26 mins
# Epoch: 001/001 | Batch 050/750 | Test Accuracy: 91.04% | Validation Accuracy: 99.30% | Time: 3.89 mins
# Epoch: 001/001 | Batch 100/750 | Test Accuracy: 91.15% | Validation Accuracy: 99.30% | Time: 7.82 mins
# Epoch: 001/001 | Batch 150/750 | Test Accuracy: 91.16% | Validation Accuracy: 99.40% | Time: 11.70 mins
# ---------------------- Quantize Layer block 2 Conv 1 1 ------------------------
# Clusters:200 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 0.40 mins
# Clusters:190 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 0.79 mins
# Clusters:180 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 1.19 mins
# Clusters:170 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 1.58 mins
# Clusters:160 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 1.97 mins
# Clusters:150 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 2.36 mins
# Clusters:140 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 2.76 mins
# Clusters:130 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 3.15 mins
# Clusters:120 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 3.55 mins
# Clusters:110 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 3.99 mins
# Clusters:100 | Validation Accuracy:99.40% | Accuracy change: 0.05% | Time: 4.43 mins
# Clusters: 95 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 4.84 mins
# Clusters: 90 | Validation Accuracy:99.40% | Accuracy change: 0.05% | Time: 5.24 mins
# Clusters: 85 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 5.62 mins
# Clusters: 80 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 5.99 mins
# Clusters: 75 | Validation Accuracy:99.25% | Accuracy change: -0.10% | Time: 6.36 mins
# Clusters: 70 | Validation Accuracy:99.25% | Accuracy change: -0.10% | Time: 6.75 mins
# Clusters: 65 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 7.13 mins
# Clusters: 62 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 7.52 mins
# Clusters: 60 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 7.90 mins
# Clusters: 58 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 8.27 mins
# Clusters: 56 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 8.64 mins
# Clusters: 54 | Validation Accuracy:99.25% | Accuracy change: -0.10% | Time: 9.01 mins
# Clusters: 52 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 9.39 mins
# Clusters: 50 | Validation Accuracy:99.35% | Accuracy change: 0.00% | Time: 9.76 mins
# Clusters: 48 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 10.13 mins
# Clusters: 46 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 10.49 mins
# Clusters: 44 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 10.85 mins
# Clusters: 42 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 11.22 mins
# Clusters: 40 | Validation Accuracy:99.30% | Accuracy change: -0.05% | Time: 11.59 mins
# Clusters: 38 | Validation Accuracy:99.20% | Accuracy change: -0.15% | Time: 11.96 mins
# Clusters: 36 | Validation Accuracy:99.20% | Accuracy change: -0.15% | Time: 12.33 mins
# End quantization
# Epoch: 001/001 | Batch 050/750 | Test Accuracy: 90.51% | Validation Accuracy: 98.85% | Time: 3.83 mins
# Epoch: 001/001 | Batch 100/750 | Test Accuracy: 90.58% | Validation Accuracy: 98.70% | Time: 7.69 mins
# Epoch: 001/001 | Batch 150/750 | Test Accuracy: 90.48% | Validation Accuracy: 98.70% | Time: 11.62 mins
# ---------------------- Quantize Layer block 2 Conv 1 2 ------------------------
# ---------------------- Quantize Layer block 2 Conv 2 1 ------------------------
# ---------------------- Quantize Layer block 2 Conv 2 2 ------------------------
# ---------------------- Quantize Layer block 3 Conv 1 1 ------------------------
# ---------------------- Quantize Layer block 3 Conv 1 2 ------------------------
# ---------------------- Quantize Layer block 3 Conv 2 1 ------------------------
# ---------------------- Quantize Layer block 3 Conv 2 2 ------------------------
# ---------------------- Quantize Layer block 4 Conv 1 1 ------------------------
# ---------------------- Quantize Layer block 4 Conv 1 2 ------------------------
# ---------------------- Quantize Layer block 4 Conv 2 1 ------------------------
# ---------------------- Quantize Layer block 4 Conv 2 2 ------------------------
# ---------------------- Quantize Layer fc ------------------------
#
# ########################## Lower bound 4 ##########################
#
# ---------------------- Quantize Layer block 1 Conv 1 1 ------------------------
# ---------------------- Quantize Layer block 1 Conv 1 2 ------------------------
# ---------------------- Quantize Layer block 1 Conv 2 1 ------------------------
# ---------------------- Quantize Layer block 1 Conv 2 2 ------------------------
# ---------------------- Quantize Layer block 2 Conv 1 1 ------------------------
# ---------------------- Quantize Layer block 2 Conv 1 2 ------------------------
# ---------------------- Quantize Layer block 2 Conv 2 1 ------------------------
# ---------------------- Quantize Layer block 2 Conv 2 2 ------------------------
# ---------------------- Quantize Layer block 3 Conv 1 1 ------------------------
# ---------------------- Quantize Layer block 3 Conv 1 2 ------------------------
# ---------------------- Quantize Layer block 3 Conv 2 1 ------------------------
# ---------------------- Quantize Layer block 3 Conv 2 2 ------------------------
